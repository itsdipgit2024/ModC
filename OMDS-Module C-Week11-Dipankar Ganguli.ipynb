# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage



from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score, classification_report

# %%
df_healthcare=pd.read_csv('capstone datasets/healthcaredatasets-DataScience/healthcare_dataset.csv')

# %% [markdown]
# ### Patient Healthcare Record Fields
#
# - **Name**: Patient’s name associated with the healthcare record.
# - **Age**: Patient’s age at the time of admission, in years.
# - **Gender**: Patient’s gender, either *"Male"* or *"Female."*
# - **Blood Type**: Patient’s blood type (e.g., *"A+"*, *"O-"*).
# - **Medical Condition**: Primary medical condition or diagnosis (e.g., *"Diabetes"*, *"Hypertension"*).
# - **Date of Admission**: Date of patient admission to the healthcare facility.
# - **Doctor**: Name of the doctor responsible for the patient’s care during admission.
# - **Hospital**: Healthcare facility or hospital where the patient was admitted.
# - **Insurance Provider**: Patient’s insurance provider (e.g., *"Aetna"*, *"Blue Cross"*).
# - **Billing Amount**: Amount billed for healthcare services, expressed as a floating-point number.
# - **Room Number**: Room number where the patient was accommodated.
# - **Admission Type**: Type of admission (*"Emergency"*, *"Elective"*, or *"Urgent"*).
# - **Discharge Date**: Date of discharge from the healthcare facility, based on admission date and a realistic range of days.
# - **Medication**: Medication prescribed or administered (e.g., *"Aspirin"*, *"Ibuprofen"*).
# - **Test Results**: Results of medical tests during admission (*"Normal"*, *"Abnormal"*, *"Inconclusive"*).

# %%
df_healthcare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.4+ MB

# %%
df_healthcare.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df_healthcare.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# #### Scatter plot

# %%
plt.boxplot(df_healthcare['Billing Amount'],)
plt.title('Boxplot of Age') 
plt.show()

# %%
plt.bar(df_healthcare['Test Results'], df_healthcare['Billing Amount'])
plt.ylabel('Billing Amount')
plt.title('Billing Amount by Gender')
plt.show()

# %%
df_healthcare.groupby('Test Results')['Billing Amount'].sum()
df_healthcare.groupby('Test Results')['Billing Amount'].mean()
df_healthcare.groupby('Test Results')['Billing Amount'].count()
df_healthcare.groupby('Test Results')['Billing Amount'].max()
df_healthcare.groupby('Test Results')['Billing Amount'].min()
df_healthcare.groupby('Test Results')['Billing Amount'].std()
df_healthcare.groupby('Test Results')['Billing Amount'].var()
df_healthcare.groupby('Test Results')['Billing Amount'].median()
df_healthcare.groupby('Test Results')['Billing Amount'].quantile(0.25)
# Out:
# Test Results
# Abnormal        13259.291956
# Inconclusive    13354.200590
# Normal          13109.077021
# Name: Billing Amount, dtype: float64

# %% [markdown]
# #### Since clustering is unsupervised learning, therefore, there is no X and y

# %%
# X=df_healthcare.drop(labels='Test Results',axis=1)
# y=df_healthcare['Test Results']

# %% [markdown]
# #### Encoding

# %%
categorical_cols = ['Gender', 'Blood Type', 'Medical Condition','Admission Type','Insurance Provider','Medication','Test Results']
numeric_cols = ['Age', 'Billing Amount']

# %%
#Encode categorical columns
df_encoded = pd.get_dummies(df_healthcare[categorical_cols], drop_first=True)

df_all = pd.concat([df_healthcare[numeric_cols], df_encoded], axis=1)
df_all.head()
# Out:
#    Age  Billing Amount  Gender_Male  Blood Type_A-  Blood Type_AB+  \
# 0   30    18856.281306         True          False           False
# 1   62    33643.327287         True          False           False
# 2   76    27955.096079        False           True           False
# 3   28    37909.782410        False          False           False
# 4   43    14238.317814        False          False            True
#
#    Blood Type_AB-  Blood Type_B+  Blood Type_B-  Blood Type_O+  Blood Type_O-  \
# 0           False          False           True          False          False
# 1           False          False          False          False          False
# 2           False          False          False          False          False
# 3           False          False          False           True          False
# 4           False          False          False          False          False
#
#    ...  Insurance Provider_Blue Cross  Insurance Provider_Cigna  \
# 0  ...                           True                     False
# 1  ...                          False                     False
# 2  ...                          False                     False
# 3  ...                          False                     False
# 4  ...                          False                     False
#
#    Insurance Provider_Medicare  Insurance Provider_UnitedHealthcare  \
# 0                        False                                False
# 1                         True                                False
# 2                        False                                False
# 3                         True                                False
# 4                        False                                False
#
#    Medication_Ibuprofen  Medication_Lipitor  Medication_Paracetamol  \
# 0                 False               False                    True
# 1                  True               False                   False
# 2                 False               False                   False
# 3                  True               False                   False
# 4                 False               False                   False
#
#    Medication_Penicillin  Test Results_Inconclusive  Test Results_Normal
# 0                  False                      False                 True
# 1                  False                       True                False
# 2                  False                      False                 True
# 3                  False                      False                False
# 4                   True                      False                False
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Feature scaling

# %% [markdown]
# This dataset has only two int columns, Age and Room Number. These two columns do not require any standardization

# %%
# scaler=StandardScaler()
# X_train_scaled=scaler.fit_transform(X_train)
# print(f'standard_features std is {X_train_scaled.std(axis=0)}')
# print(f'standard_features mean is {X_train_scaled.mean(axis=0)}')

# X_test_scaled=scaler.transform(X_test)
# print(f'standard_features std is {X_test_scaled.std(axis=0)}')
# print(f'standard_features mean is {X_test_scaled.mean(axis=0)}')

# %%
df_all.isnull().sum().sum()  # Should return 0
# Out:
# np.int64(0)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_all[numeric_cols])

# %% [markdown]
# #### DBSCAN model

# %%
for eps in [0.5, 0.3, 0.2, 0.1]:
    db = DBSCAN(eps=eps, min_samples=5)
    labels = db.fit_predict(X_scaled)
    print(f"eps={eps}: clusters = {len(set(labels))}, noise points = {sum(labels == -1)}")
# Out:
# eps=0.5: clusters = 1, noise points = 0
# eps=0.3: clusters = 1, noise points = 0
# eps=0.2: clusters = 1, noise points = 0
# eps=0.1: clusters = 3, noise points = 32

# %%
dbscan = DBSCAN(eps=0.1, min_samples=5)
labels = dbscan.fit_predict(X_scaled)
df_healthcare['Cluster'] = labels

# %% [markdown]
# #### Setting DBSCAN model and prediction

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df_healthcare['Cluster'], cmap='tab10', s=15)
plt.title("DBSCAN Clusters Visualized (PCA 2D)")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar(label='Cluster')
plt.show()

# %%
df_healthcare[df_healthcare['Cluster'] == -1]
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 36349        tOdd CARrILlO   51  Female         A+      Hypertension
# 50210    alExAndeR SHannON   16    Male         A-      Hypertension
# 50214       maTThew tAYLOr   88    Male         A+            Asthma
# 50321       BARBaRA OSbOrN   88  Female         O+            Asthma
# 50367        JOSepH vAuGHN   88    Male         B-          Diabetes
# 50763         noAh RObErTS   15  Female         A+            Cancer
# 50823        DEaNnA pALMeR   13    Male        AB-           Obesity
# 50908         rOnalD daVis   13    Male         A+           Obesity
# 51095         cAthY BARNES   13    Male         O-           Obesity
# 51833     JoNaTHAn JacksoN   13  Female         B-           Obesity
# 51900       jAcob wILLiAMs   13  Female         A+           Obesity
# 52043         DAVId NeWTOn   89  Female         O+         Arthritis
# 52172       CHArlEs joRDAN   13    Male         A+         Arthritis
# 52371    CourtNey ThoMPson   15  Female         B-           Obesity
# 52703         MaRIA BeckEr   14    Male        AB+           Obesity
# 52767       MIChaEL MUrraY   88  Female        AB-         Arthritis
# 52791         eDwarD sMITH   88    Male        AB+          Diabetes
# 52828         doNALD aViLA   89  Female        AB-            Asthma
# 52851     StephaNIE FIshEr   88  Female        AB+            Asthma
# 52857      THomAs PHIllIpS   89  Female         A+      Hypertension
# 52945           lIsA Clark   15    Male         O-            Cancer
# 53596          PeTEr bAuer   88  Female         O+      Hypertension
# 53673         CALeB MADDoX   14  Female        AB-         Arthritis
# 53694     RUsSelL FiGuErOa   16    Male         A-          Diabetes
# 54302          dAWn chAveZ   13    Male        AB+            Cancer
# 54494           DaviD Shaw   14  Female         A+            Cancer
# 54670           jaDe BaKER   88  Female         O-           Obesity
# 54939        kaThleen boyD   15  Female         A-      Hypertension
# 55185         Laura bUTlER   87  Female         B-          Diabetes
# 55227              jIm DAY   14    Male         O-         Arthritis
# 55382        kRiStiN orTIZ   13    Male         A-            Asthma
# 55483  kimbErlY RIchArDSoN   15    Male         A-          Diabetes
#
#       Date of Admission             Doctor                         Hospital  \
# 36349        2023-09-08   Kathleen Griffin                    Griffin Group
# 50210        2023-03-31  Mrs. Erin Aguirre                      Mcgee-Brady
# 50214        2022-07-14   Mr. Derrick Knox             Cain and Gay Thomas,
# 50321        2020-03-10      Robert Medina                  Rangel-Phillips
# 50367        2019-12-31        Wanda Barry           Chaney, Cook Tyler and
# 50763        2022-02-20        Keith Henry                   Sons and Heath
# 50823        2020-09-20     Barbara Butler      and Sanchez Phillips, Brown
# 54670   UnitedHealthcare     1990.269053          488         Urgent
# 54939   UnitedHealthcare    43811.458350          313         Urgent
# 55185   UnitedHealthcare    19995.351052          497       Elective
# 55227         Blue Cross     1539.611297          238       Elective
# 55382   UnitedHealthcare    50526.712855          493         Urgent
# 55483         Blue Cross    12239.838237          177       Elective
#
#       Discharge Date   Medication  Test Results  Cluster
# 36349     2023-10-04    Ibuprofen        Normal       -1
# 50210     2023-04-23  Paracetamol        Normal       -1
# 50214     2022-07-26    Ibuprofen  Inconclusive       -1
# 50321     2020-03-29    Ibuprofen        Normal       -1
# 50367     2020-01-29      Lipitor        Normal       -1
# 50763     2022-03-01  Paracetamol        Normal       -1
# 50823     2020-09-23   Penicillin  Inconclusive       -1
# 50908     2024-01-04  Paracetamol        Normal       -1
# 51095     2023-04-29      Lipitor      Abnormal       -1
# 51833     2020-02-24      Aspirin  Inconclusive       -1
# 51900     2020-03-20    Ibuprofen        Normal       -1
# 52043     2021-02-20   Penicillin  Inconclusive       -1
# 52172     2021-06-12   Penicillin        Normal       -1
# 52371     2022-11-17   Penicillin      Abnormal       -1
# 52703     2023-03-14      Aspirin        Normal       -1
# 52767     2020-01-19    Ibuprofen  Inconclusive       -1
# 52791     2019-09-21   Penicillin  Inconclusive       -1
# 52828     2022-09-27      Aspirin      Abnormal       -1
# 52851     2022-03-12      Aspirin        Normal       -1
# 52857     2022-05-26   Penicillin  Inconclusive       -1
# 52945     2022-08-09    Ibuprofen        Normal       -1
# 53596     2019-08-18      Lipitor  Inconclusive       -1
# 53673     2020-02-04      Aspirin      Abnormal       -1
# 53694     2023-10-16  Paracetamol        Normal       -1
# 54302     2023-03-25    Ibuprofen      Abnormal       -1
# 54494     2019-11-22      Lipitor      Abnormal       -1
# 54670     2021-06-03      Lipitor        Normal       -1
# 54939     2021-02-19   Penicillin        Normal       -1
# 55185     2023-08-18      Lipitor  Inconclusive       -1
# 55227     2021-06-28      Aspirin      Abnormal       -1
# 55382     2020-04-02  Paracetamol      Abnormal       -1
# 55483     2022-07-05      Lipitor      Abnormal       -1

# %% [markdown]
# #### Hierarchical Agglomerative Clustering

# %%
# Example: using your df_all from earlier
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_all)

# %%
# You can change n_clusters or try different linkage methods: 'ward', 'complete', 'average', 'single'
hac = AgglomerativeClustering(n_clusters=3, linkage='ward')
labels = hac.fit_predict(X_scaled)

# %%
df_healthcare['HAC_Cluster'] = labels

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=labels, palette='tab10')
plt.title("HAC Clusters Visualized (PCA)")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.legend(title='Cluster')
plt.grid()
plt.show()

# %%
linked = linkage(X_scaled, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(linked, truncate_mode='level', p=5)
plt.title("Hierarchical Clustering Dendrogram (Truncated)")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()
